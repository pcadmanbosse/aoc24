# %%
import re
import networkx as nx 
# importing matplotlib.pyplot
import matplotlib.pyplot as plt

with open("input.txt") as f:
    [gates, insts] = f.read().split("\n\n")
    gates = gates.split("\n")
    insts = insts.split("\n")

status = {}

for gate in gates:
    [g, op] = gate.split(": ")
    status[g] = True if op == "1" else False


def process(a, b, op):
    if op == "OR":
        return a or b
    if op == "AND":
        return a and b
    if op == "XOR":
        return a != b
    
r = r"(.*) (AND|OR|XOR) (.*) -> (.*)"
while len(insts) > 0:
    inst = insts.pop(0)
    patts = re.match(r, inst)
    a = patts[1]
    op = patts[2]
    b = patts[3]
    result_loc = patts[4]
    if (a not in status) or (b not in status):
        insts.append(inst)
        continue
    status[result_loc] = process(status[a], status[b], op)

bits = []
for k in reversed(sorted([k for k in status.keys() if k.startswith("z")])):
    bits.append(1 if status[k] else 0)

print(''.join([str(x) for x in bits]))
print(int(''.join([str(x) for x in bits]), 2))


# Part 2:
mermaid = ""

with open("input.txt") as f:
    [gates, insts] = f.read().split("\n\n")
    gates = gates.split("\n")
    insts = insts.split("\n")
for inst in insts:

    patts = re.match(r, inst)
    a = patts[1]
    op = patts[2]
    b = patts[3]
    result_loc = patts[4]

    mermaid+="\n"
    mermaid+=f"{a} -->|{op}| {result_loc}"
    mermaid+="\n"
    mermaid+=f"{b} -->|{op}| {result_loc}"
    mermaid+="\n"
# Out:
# 1100110111111100011000100101110111011101100110
# 56620966442854

# %%
print(mermaid)
# Out:
# x03 -->|AND| htr
# y03 -->|AND| htr
#
# gwb -->|AND| pkd
# kvf -->|AND| pkd
#
# x04 -->|AND| jjm
# y04 -->|AND| jjm
#
# qcm -->|XOR| z21
# twv -->|XOR| z21
#
# rrq -->|XOR| z44
# bmp -->|XOR| z44
#
# x43 -->|AND| pnn
# y43 -->|AND| pnn
#
# x06 -->|XOR| qmt
# y06 -->|XOR| qmt
#
# x26 -->|AND| z26
# y26 -->|AND| z26
#
# y00 -->|AND| whb
# x00 -->|AND| whb
#
# jfq -->|XOR| z36
# fbb -->|XOR| z36
#
# y33 -->|AND| mmb
# x33 -->|AND| mmb
#
# x38 -->|AND| vqt
# y38 -->|AND| vqt
#
# bbh -->|OR| jfq
# qtd -->|OR| jfq
#
# cbs -->|AND| qtd
# ttb -->|AND| qtd
#
# wqs -->|OR| tpf
# cmf -->|OR| tpf
#
# x10 -->|AND| bfm
# y10 -->|AND| bfm
#
# djp -->|OR| qvr
# pfb -->|OR| qvr
#
# x20 -->|XOR| vhb
# y20 -->|XOR| vhb
#
# kkd -->|XOR| z32
# cjg -->|XOR| z32
#
# qpp -->|XOR| z41
# stg -->|XOR| z41
#
# kkd -->|AND| mdv
# cjg -->|AND| mdv
#
# tpp -->|OR| twv
# pfj -->|OR| twv
#
# www -->|AND| vjf
# qdf -->|AND| vjf
#
# y15 -->|XOR| hmr
# x15 -->|XOR| hmr
#
# mtg -->|XOR| z09
# sqm -->|XOR| z09
#
# x33 -->|XOR| chc
# y33 -->|XOR| chc
#
# x41 -->|AND| pkj
# y41 -->|AND| pkj
#
# x31 -->|AND| cvn
# y31 -->|AND| cvn
#
# x09 -->|AND| nvw
# y09 -->|AND| nvw
#
# mtg -->|AND| chg
# sqm -->|AND| chg
#
# pkr -->|AND| thc
# kcv -->|AND| thc
#
# x07 -->|XOR| cds
# y07 -->|XOR| cds
#
# x15 -->|AND| fpr
# y15 -->|AND| fpr
#
# mwv -->|AND| wdw
# jsg -->|AND| wdw
#
# mwv -->|XOR| z38
# jsg -->|XOR| z38
#
# y16 -->|XOR| svs
# x16 -->|XOR| svs
#
# y14 -->|XOR| fnq
# x14 -->|XOR| fnq
#
# wth -->|OR| btv
# vjf -->|OR| btv
#
# bvp -->|AND| stc
# gdb -->|AND| stc
#
# cjb -->|XOR| z04
# rjc -->|XOR| z04
#
# x13 -->|AND| pfb
# y13 -->|AND| pfb
#
# x30 -->|AND| qgf
# y30 -->|AND| qgf
#
# htq -->|AND| dsm
# rtk -->|AND| dsm
#
# x18 -->|XOR| kvf
# y18 -->|XOR| kvf
#
# y12 -->|AND| mqn
# x12 -->|AND| mqn
#
# bcj -->|XOR| z03
# bkh -->|XOR| z03
#
# x07 -->|AND| sdj
# y07 -->|AND| sdj
#
# bdf -->|OR| qkf
# wbw -->|OR| qkf
#
# y30 -->|XOR| kbn
# x30 -->|XOR| kbn
#
# tpf -->|AND| tpp
# vhb -->|AND| tpp
#
# hqd -->|OR| hgh
# fpr -->|OR| hgh
#
# vfm -->|XOR| z23
# hbw -->|XOR| z23
#
# x01 -->|AND| bdf
# y01 -->|AND| bdf
#
# nvw -->|OR| vgp
# chg -->|OR| vgp
#
# x21 -->|XOR| qcm
# y21 -->|XOR| qcm
#
# bwg -->|AND| djp
# mfn -->|AND| djp
#
# dnf -->|OR| ksp
# pkj -->|OR| ksp
#
# y44 -->|AND| gqr
# x44 -->|AND| gqr
#
# y11 -->|AND| smr
# x11 -->|AND| smr
#
# smr -->|OR| ksn
# dsm -->|OR| ksn
#
# jkm -->|OR| rjf
# pkd -->|OR| rjf
#
# thc -->|OR| rbd
# sqt -->|OR| rbd
#
# qvr -->|XOR| z14
# fnq -->|XOR| z14
#
# cjb -->|AND| fsb
# rjc -->|AND| fsb
#
# svg -->|XOR| z31
# fmt -->|XOR| z31
#
# x06 -->|AND| ssv
# y06 -->|AND| ssv
#
# dtj -->|OR| jvp
# vvq -->|OR| jvp
#
# chv -->|XOR| z34
# fqf -->|XOR| z34
#
# cvr -->|AND| pjd
# hck -->|AND| pjd
#
# dqp -->|AND| hvv
# nbm -->|AND| hvv
#
# x29 -->|AND| vvq
# y29 -->|AND| vvq
#
# y13 -->|XOR| mfn
# x13 -->|XOR| mfn
#
# ksn -->|AND| z12
# nft -->|AND| z12
#
# jjd -->|XOR| z01
# whb -->|XOR| z01
#
# chc -->|AND| vjh
# rnq -->|AND| vjh
#
# y36 -->|AND| kfn
# x36 -->|AND| kfn
#
# cwh -->|OR| ttb
# vvw -->|OR| ttb
#
# qkf -->|AND| pqc
# wsv -->|AND| pqc
#
# rdj -->|OR| gdb
# kfv -->|OR| gdb
#
# x08 -->|AND| jrr
# y08 -->|AND| jrr
#
# x02 -->|AND| vdf
# y02 -->|AND| vdf
#
# x12 -->|XOR| nft
# y12 -->|XOR| nft
#
# ptf -->|OR| sqm
# jrr -->|OR| sqm
#
# tdv -->|OR| cjw
# wjp -->|OR| cjw
#
# qvr -->|AND| mch
# fnq -->|AND| mch
#
# x28 -->|XOR| cfj
# y28 -->|XOR| cfj
#
# gtn -->|XOR| z06
# qmt -->|XOR| z06
#
# mqn -->|OR| bwg
# jpj -->|OR| bwg
#
# x36 -->|XOR| fbb
# y36 -->|XOR| fbb
#
# qht -->|OR| htq
# bfm -->|OR| htq
#
# y42 -->|AND| mkg
# x42 -->|AND| mkg
#
# ksn -->|XOR| jpj
# nft -->|XOR| jpj
#
# x20 -->|AND| pfj
# y20 -->|AND| pfj
#
# cmt -->|AND| gmc
# nbq -->|AND| gmc
#
# rbd -->|XOR| z25
# knm -->|XOR| z25
#
# pvj -->|XOR| z42
# ksp -->|XOR| z42
#
# kgj -->|OR| www
# stc -->|OR| www
#
# tpf -->|XOR| z20
# vhb -->|XOR| z20
#
# pjd -->|OR| mwv
# dsg -->|OR| mwv
#
# cbs -->|XOR| z35
# ttb -->|XOR| z35
#
# bfk -->|OR| gwb
# jvm -->|OR| gwb
#
# ffj -->|XOR| z17
# rpg -->|XOR| z17
#
# vjr -->|OR| pkr
# kwg -->|OR| pkr
#
# pvj -->|AND| dkc
# ksp -->|AND| dkc
#
# y37 -->|XOR| cvr
# x37 -->|XOR| cvr
#
# btv -->|XOR| z28
# cfj -->|XOR| z28
#
# gtq -->|OR| fmt
# qgf -->|OR| fmt
#
# nbq -->|XOR| z39
# cmt -->|XOR| z39
#
# wgq -->|AND| tws
# dqj -->|AND| tws
#
# x24 -->|AND| sqt
# y24 -->|AND| sqt
#
# whj -->|OR| bmp
# pnn -->|OR| bmp
#
# x02 -->|XOR| wsv
# y02 -->|XOR| wsv
#
# stg -->|AND| dnf
# qpp -->|AND| dnf
#
# kbn -->|XOR| z30
# jvp -->|XOR| z30
#
# y39 -->|AND| gwq
# x39 -->|AND| gwq
#
# cds -->|AND| nph
# rkv -->|AND| nph
#
# kvf -->|XOR| z18
# gwb -->|XOR| z18
#
# mkg -->|OR| sch
# dkc -->|OR| sch
#
# bqh -->|XOR| z19
# rjf -->|XOR| z19
#
# hck -->|XOR| z37
# cvr -->|XOR| z37
#
# jmk -->|OR| rkv
# ssv -->|OR| rkv
#
# x21 -->|AND| cgd
# y21 -->|AND| cgd
#
# pqc -->|OR| bkh
# vdf -->|OR| bkh
#
# rff -->|OR| rpg
# mts -->|OR| rpg
#
# bkh -->|AND| rhq
# bcj -->|AND| rhq
#
# bnv -->|OR| stg
# bst -->|OR| stg
#
# bwg -->|XOR| z13
# mfn -->|XOR| z13
#
# sgt -->|AND| bnv
# scc -->|AND| bnv
#
# btv -->|AND| tdv
# cfj -->|AND| tdv
#
# svs -->|AND| rff
# hgh -->|AND| rff
#
# hbw -->|AND| kwg
# vfm -->|AND| kwg
#
# x40 -->|XOR| scc
# y40 -->|XOR| scc
#
# y17 -->|AND| jvm
# x17 -->|AND| jvm
#
# y34 -->|AND| chv
# x34 -->|AND| chv
#
# y35 -->|AND| bbh
# x35 -->|AND| bbh
#
# mdv -->|OR| rnq
# rft -->|OR| rnq
#
# fqf -->|AND| cwh
# chv -->|AND| cwh
#
# y28 -->|AND| wjp
# x28 -->|AND| wjp
#
# sch -->|AND| whj
# srj -->|AND| whj
#
# htr -->|OR| rjc
# rhq -->|OR| rjc
#
# x05 -->|XOR| dqp
# y05 -->|XOR| dqp
#
# cvn -->|OR| cjg
# qnk -->|OR| cjg
#
# y14 -->|AND| tfr
# x14 -->|AND| tfr
#
# y11 -->|XOR| rtk
# x11 -->|XOR| rtk
#
# jfq -->|AND| trr
# fbb -->|AND| trr
#
# ppb -->|AND| hqd
# hmr -->|AND| hqd
#
# gtb -->|OR| gtn
# hvv -->|OR| gtn
#
# y44 -->|XOR| rrq
# x44 -->|XOR| rrq
#
# rtk -->|XOR| z11
# htq -->|XOR| z11
#
# x01 -->|XOR| jjd
# y01 -->|XOR| jjd
#
# hmv -->|XOR| z08
# rts -->|XOR| z08
#
# y10 -->|XOR| vpc
# x10 -->|XOR| vpc
#
# jvp -->|AND| gtq
# kbn -->|AND| gtq
#
# cjw -->|AND| dtj
# ntj -->|AND| dtj
#
# x22 -->|AND| prp
# y22 -->|AND| prp
#
# ppb -->|XOR| z15
# hmr -->|XOR| z15
#
# y18 -->|AND| jkm
# x18 -->|AND| jkm
#
# x39 -->|XOR| nbq
# y39 -->|XOR| nbq
#
# jjd -->|AND| wbw
# whb -->|AND| wbw
#
# x34 -->|XOR| vvw
# y34 -->|XOR| vvw
#
# x19 -->|AND| wqs
# y19 -->|AND| wqs
#
# gwq -->|OR| sgt
# gmc -->|OR| sgt
#
# rbd -->|AND| rdj
# knm -->|AND| rdj
#
# srj -->|XOR| z43
# sch -->|XOR| z43
#
# y05 -->|AND| gtb
# x05 -->|AND| gtb
#
# x08 -->|XOR| hmv
# y08 -->|XOR| hmv
#
# y25 -->|AND| kfv
# x25 -->|AND| kfv
#
# cgd -->|OR| dqj
# jth -->|OR| dqj
#
# vpc -->|XOR| z10
# vgp -->|XOR| z10
#
# tws -->|OR| hbw
# prp -->|OR| hbw
#
# jjm -->|OR| nbm
# fsb -->|OR| nbm
#
# wdw -->|OR| cmt
# vqt -->|OR| cmt
#
# rrq -->|AND| cbv
# bmp -->|AND| cbv
#
# rts -->|AND| ptf
# hmv -->|AND| ptf
#
# svs -->|XOR| z16
# hgh -->|XOR| z16
#
# y41 -->|XOR| qpp
# x41 -->|XOR| qpp
#
# ntj -->|XOR| z29
# cjw -->|XOR| z29
#
# ffj -->|AND| bfk
# rpg -->|AND| bfk
#
# gqr -->|OR| z45
# cbv -->|OR| z45
#
# x25 -->|XOR| knm
# y25 -->|XOR| knm
#
# chc -->|XOR| z33
# rnq -->|XOR| z33
#
# y43 -->|XOR| srj
# x43 -->|XOR| srj
#
# vgp -->|AND| qht
# vpc -->|AND| qht
#
# x00 -->|XOR| z00
# y00 -->|XOR| z00
#
# cds -->|XOR| rts
# rkv -->|XOR| rts
#
# x24 -->|XOR| kcv
# y24 -->|XOR| kcv
#
# x32 -->|AND| rft
# y32 -->|AND| rft
#
# nbm -->|XOR| z05
# dqp -->|XOR| z05
#
# x35 -->|XOR| cbs
# y35 -->|XOR| cbs
#
# mch -->|OR| ppb
# tfr -->|OR| ppb
#
# x16 -->|AND| mts
# y16 -->|AND| mts
#
# www -->|XOR| z27
# qdf -->|XOR| z27
#
# x23 -->|AND| vjr
# y23 -->|AND| vjr
#
# x26 -->|XOR| bvp
# y26 -->|XOR| bvp
#
# gtn -->|AND| jmk
# qmt -->|AND| jmk
#
# x29 -->|XOR| ntj
# y29 -->|XOR| ntj
#
# y19 -->|XOR| bqh
# x19 -->|XOR| bqh
#
# rjf -->|AND| cmf
# bqh -->|AND| cmf
#
# y38 -->|XOR| jsg
# x38 -->|XOR| jsg
#
# x32 -->|XOR| kkd
# y32 -->|XOR| kkd
#
# y03 -->|XOR| bcj
# x03 -->|XOR| bcj
#
# y31 -->|XOR| svg
# x31 -->|XOR| svg
#
# y22 -->|XOR| wgq
# x22 -->|XOR| wgq
#
# qkf -->|XOR| z02
# wsv -->|XOR| z02
#
# bvp -->|XOR| kgj
# gdb -->|XOR| kgj
#
# x04 -->|XOR| cjb
# y04 -->|XOR| cjb
#
# x17 -->|XOR| ffj
# y17 -->|XOR| ffj
#
# y37 -->|AND| dsg
# x37 -->|AND| dsg
#
# y27 -->|AND| wth
# x27 -->|AND| wth
#
# y23 -->|XOR| vfm
# x23 -->|XOR| vfm
#
# sgt -->|XOR| z40
# scc -->|XOR| z40
#
# mmb -->|OR| fqf
# vjh -->|OR| fqf
#
# qcm -->|AND| jth
# twv -->|AND| jth
#
# y09 -->|XOR| mtg
# x09 -->|XOR| mtg
#
# sdj -->|OR| z07
# nph -->|OR| z07
#
# wgq -->|XOR| z22
# dqj -->|XOR| z22
#
# trr -->|OR| hck
# kfn -->|OR| hck
#
# y27 -->|XOR| qdf
# x27 -->|XOR| qdf
#
# kcv -->|XOR| z24
# pkr -->|XOR| z24
#
# x42 -->|XOR| pvj
# y42 -->|XOR| pvj
#
# x40 -->|AND| bst
# y40 -->|AND| bst
#
# svg -->|AND| qnk
# fmt -->|AND| qnk

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/networkx/drawing/nx_agraph.py:134, in to_agraph(N)
#     133 try:
# --> 134     import pygraphviz
#     135 except ImportError as err:
#
# ModuleNotFoundError: No module named 'pygraphviz'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 A = nx.nx_agraph.to_agraph(G)
#       3 # Customize Graphviz settings
#       4 A.node_attr.update(style='filled', color='lightblue', shape='circle')
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/networkx/drawing/nx_agraph.py:136, in to_agraph(N)
#     134     import pygraphviz
#     135 except ImportError as err:
# --> 136     raise ImportError("requires pygraphviz http://pygraphviz.github.io/") from err
#     137 directed = N.is_directed()
#     138 strict = nx.number_of_selfloops(N) == 0 and not N.is_multigraph()
#
# ImportError: requires pygraphviz http://pygraphviz.github.io/
